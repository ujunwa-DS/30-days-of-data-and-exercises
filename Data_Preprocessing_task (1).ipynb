# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# Attached to this notebook is a dataset.

# %% [markdown]
# 1. Import the dataset into your notebook, print out the first 10 rows, check the statistical and general information

# %%
import numpy as np
import pandas as pd
dataset=pd.read_csv("hepatitis.csv")

# %%
dataset.head()
# Out:
#    age     sex steroid  antivirals fatigue malaise anorexia liver_big  \
# 0   30    male   False       False   False   False    False     False
# 1   50  female   False       False    True   False    False     False
# 2   78  female    True       False    True   False    False      True
# 3   31  female     NaN        True   False   False    False      True
# 4   34  female    True       False   False   False    False      True
#
#   liver_firm spleen_palpable spiders ascites varices  bilirubin  \
# 0      False           False   False   False   False        1.0
# 1      False           False   False   False   False        0.9
# 2      False           False   False   False   False        0.7
# 3      False           False   False   False   False        0.7
# 4      False           False   False   False   False        1.0
#
#    alk_phosphate   sgot  albumin  protime  histology class
# 0           85.0   18.0      4.0      NaN      False  live
# ...

# %%
dataset.loc[:10]
# Out:
#     age     sex steroid  antivirals fatigue malaise anorexia liver_big  \
# 0    30    male   False       False   False   False    False     False
# 1    50  female   False       False    True   False    False     False
# 2    78  female    True       False    True   False    False      True
# 3    31  female     NaN        True   False   False    False      True
# 4    34  female    True       False   False   False    False      True
# 5    34  female    True       False   False   False    False      True
# 6    51  female   False       False    True   False     True      True
# 7    23  female    True       False   False   False    False      True
# 8    39  female    True       False    True   False    False      True
# 9    30  female    True       False   False   False    False      True
# 10   39  female   False        True   False   False    False     False
#
#    liver_firm spleen_palpable spiders ascites varices  bilirubin  \
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              155 non-null    int64
#  1   sex              155 non-null    object
#  2   steroid          154 non-null    object
#  3   antivirals       155 non-null    bool
#  4   fatigue          154 non-null    object
#  5   malaise          154 non-null    object
#  6   anorexia         154 non-null    object
#  7   liver_big        145 non-null    object
#  8   liver_firm       144 non-null    object
#  9   spleen_palpable  150 non-null    object
#  10  spiders          150 non-null    object
#  11  ascites          150 non-null    object
#  12  varices          150 non-null    object
#  13  bilirubin        149 non-null    float64
#  14  alk_phosphate    126 non-null    float64
#  15  sgot             151 non-null    float64
# ...

# %% [markdown]
# 2. Check for the sum of the missing values and the percentage of missing values.

# %%
dataset.isna().sum()
# Out:
# age                 0
# sex                 0
# steroid             1
# antivirals          0
# fatigue             1
# malaise             1
# anorexia            1
# liver_big          10
# liver_firm         11
# spleen_palpable     5
# spiders             5
# ascites             5
# varices             5
# bilirubin           6
# alk_phosphate      29
# sgot                4
# albumin            16
# protime            67
# histology           0
# class               0
# dtype: int64

# %%
dataset.isna().sum() *100/ len(dataset)
# Out:
# age                 0.000000
# sex                 0.000000
# steroid             0.645161
# antivirals          0.000000
# fatigue             0.645161
# malaise             0.645161
# anorexia            0.645161
# liver_big           6.451613
# liver_firm          7.096774
# spleen_palpable     3.225806
# spiders             3.225806
# ascites             3.225806
# varices             3.225806
# bilirubin           3.870968
# alk_phosphate      18.709677
# sgot                2.580645
# albumin            10.322581
# protime            43.225806
# histology           0.000000
# class               0.000000
# dtype: float64

# %% [markdown]
# 3. Choose one option: Drop the columns with missing values or fill the columns with missing values. Give your reasons.

# %%
work1=dataset.fillna(method="bfill")
work1
# Out:
#      age     sex  steroid  antivirals  fatigue  malaise  anorexia  liver_big  \
# 0     30    male    False       False    False    False     False      False
# 1     50  female    False       False     True    False     False      False
# 2     78  female     True       False     True    False     False       True
# 3     31  female     True        True    False    False     False       True
# 4     34  female     True       False    False    False     False       True
# ..   ...     ...      ...         ...      ...      ...       ...        ...
# 150   46  female     True       False     True     True      True       True
# 151   44  female     True       False     True    False     False       True
# 152   61  female    False       False     True     True     False      False
# 153   53    male    False       False     True    False     False       True
# 154   43  female     True       False     True    False     False       True
#
# ...

# %%
#I choose to fill it because there is alot of missing data so dropping the missing values will leave me with few data which will not give me a good information

# %% [markdown]
# 4. Choose a column and rename it. Give your reasons for picking that column

# %%
work1.rename(columns={"class":"status"},inplace=True)
work1
# Out:
#      age     sex  steroid  antivirals  fatigue  malaise  anorexia  liver_big  \
# 0     30    male    False       False    False    False     False      False
# 1     50  female    False       False     True    False     False      False
# 2     78  female     True       False     True    False     False       True
# 3     31  female     True        True    False    False     False       True
# 4     34  female     True       False    False    False     False       True
# ..   ...     ...      ...         ...      ...      ...       ...        ...
# 150   46  female     True       False     True     True      True       True
# 151   44  female     True       False     True    False     False       True
# 152   61  female    False       False     True     True     False      False
# 153   53    male    False       False     True    False     False       True
# 154   43  female     True       False     True    False     False       True
#
# ...

# %%
# looking at the file, the "class" doesnt really explain if the person is alive or dead so Status is a more suitable name. Meanwhile other columns has the name of a particular thing present in the patient and changing their name will alter the dataset.

# %% [markdown]
# 5. Check the number of missing values after cleaning and state the impact on data analysis.

# %%
work1.isna().sum()
# Out:
# age                0
# sex                0
# steroid            0
# antivirals         0
# fatigue            0
# malaise            0
# anorexia           0
# liver_big          0
# liver_firm         0
# spleen_palpable    0
# spiders            0
# ascites            0
# varices            0
# bilirubin          0
# alk_phosphate      0
# sgot               0
# albumin            0
# protime            0
# histology          0
# status             0
# dtype: int64

# %%
#After cleaning the datase, the data is neater now and can be fully analysed. The dataset now shows good information which the analyst needs
